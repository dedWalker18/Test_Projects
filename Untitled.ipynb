# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import jovian

# %%
df3 = pd.read_csv('./glassdoor_jobs.csv')

# %%
df = df3.copy()

# %%
df.shape
# Out:
# (1000, 14)

# %%
df2 = df.copy()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          1000 non-null   object
#  1   Salary Estimate    1000 non-null   object
#  2   Job Description    1000 non-null   object
#  3   Rating             1000 non-null   float64
#  4   Company Name       1000 non-null   object
#  5   Location           1000 non-null   object
#  6   Headquarters       1000 non-null   object
#  7   Size               1000 non-null   object
#  8   Founded            1000 non-null   int64
#  9   Type of ownership  1000 non-null   object
#  10  Industry           1000 non-null   object
#  11  Sector             1000 non-null   object
#  12  Revenue            1000 non-null   object
#  13  Competitors        1000 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 109.5+ KB

# %%
df3.columns = [c.replace(' ', '_') for c in df3.columns]

# %%
df3.Salary_Estimate.unique()
# Out:
# array(['$77K-$92K (Glassdoor Est.)', '$108K-$140K (Glassdoor Est.)',
#        '$ 17-$ 23 Per Hour(Glassdoor Est.)',
#        '$90K-$109K (Glassdoor Est.)', '$106K-$143K (Glassdoor Est.)',
#        '$41K-$73K (Glassdoor Est.)', '$139K-$229K (Glassdoor Est.)',
#        '$105K-$117K (Glassdoor Est.)', '$57K-$94K (Glassdoor Est.)',
#        '$95K-$165K (Glassdoor Est.)', '$50K-$63K (Glassdoor Est.)',
#        '$48K-$91K (Glassdoor Est.)', '$110K-$145K (Glassdoor Est.)',
#        '$70K-$119K (Glassdoor Est.)', '$72K-$121K (Glassdoor Est.)',
#        '$49K-$88K (Glassdoor Est.)', '$125K-$156K (Glassdoor Est.)',
#        '$68K-$119K (Glassdoor Est.)', '$73K-$128K (Glassdoor Est.)',
#        '$86K-$108K (Glassdoor Est.)', '$92K-$146K (Glassdoor Est.)',
#        '$83K-$99K (Glassdoor Est.)', '$88K-$133K (Glassdoor Est.)',
#        '$112K-$149K (Glassdoor Est.)', '$71K-$108K (Glassdoor Est.)',
#        '$60K-$124K (Glassdoor Est.)', '$81K-$102K (Glassdoor Est.)',
# ...

# %%
df3.Job_Title.unique()
# Out:
# array(['Data Scientist', 'Senior Data Engineer',
#        'Associate Director, Data Science', 'Senior Data Scientist',
#        'Quality Control Scientist', 'Analytics Manager - Data Mart',
#        'Scientist, Population Genomics', 'Sr Data Scientist',
#        'Data Engineer',
#        'Scientist/Research Associate-Metabolic Engineering',
#        'Senior Scientist, DMPK',
#        'Principal Data Scientist (Computational Chemistry)',
#        'Chief Data Scientist', 'Report Writer-Data Analyst',
#        'Sr Scientist/Sr Engineer Technical Transfer - Lexington, MA, US',
#        'Scientist/Engineer Technical Transfer - Lexington, MA, US',
#        'Data Analytics Engineer',
#        'Senior Scientist, AAV Plasmid and Vector Platform Development',
#        'Risk and Analytics IT, Data Scientist',
#        'Scientist, Upstream Process Development (Bioreactors)',
#        'Head of Real-World Data Science', 'Food Scientist - Developer',
# ...

# %%
#df3['type'] = df3['Job_Title'].apply(lambda x: 'Scientist' if 'scientist' in x.lower() else 0)
#df3['type'] = df3['Job_Title'].apply(lambda x: 'Engineer' if 'engineer' in x.lower() else )
df3['type'] = df3['Job_Title'].apply(lambda x: 'Analyst' if 'analyst' in x.lower() 
                                     else ('Scientist' if 'scientist' in x.lower() 
                                           else ('Engineer' if 'engineer' in x.lower() else 'Other')))

# %%
df3
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df3.loc[df3['type']=='Scientist'].shape
# Out:
# (759, 15)

# %%
df3
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df3.Salary_Estimate.unique()
# Out:
# array(['$77K-$92K (Glassdoor Est.)', '$108K-$140K (Glassdoor Est.)',
#        '$ 17-$ 23 Per Hour(Glassdoor Est.)',
#        '$90K-$109K (Glassdoor Est.)', '$106K-$143K (Glassdoor Est.)',
#        '$41K-$73K (Glassdoor Est.)', '$139K-$229K (Glassdoor Est.)',
#        '$105K-$117K (Glassdoor Est.)', '$57K-$94K (Glassdoor Est.)',
#        '$95K-$165K (Glassdoor Est.)', '$50K-$63K (Glassdoor Est.)',
#        '$48K-$91K (Glassdoor Est.)', '$110K-$145K (Glassdoor Est.)',
#        '$70K-$119K (Glassdoor Est.)', '$72K-$121K (Glassdoor Est.)',
#        '$49K-$88K (Glassdoor Est.)', '$125K-$156K (Glassdoor Est.)',
#        '$68K-$119K (Glassdoor Est.)', '$73K-$128K (Glassdoor Est.)',
#        '$86K-$108K (Glassdoor Est.)', '$92K-$146K (Glassdoor Est.)',
#        '$83K-$99K (Glassdoor Est.)', '$88K-$133K (Glassdoor Est.)',
#        '$112K-$149K (Glassdoor Est.)', '$71K-$108K (Glassdoor Est.)',
#        '$60K-$124K (Glassdoor Est.)', '$81K-$102K (Glassdoor Est.)',
# ...

# %%
df3.Salary_Estimate[0][1:3] + '-' + df3.Salary_Estimate[0][6:8]
# Out:
# '77-92'

# %%
df4 = df3.copy()

# %%
df4['Salary_Estimate_No'] = df4['Salary_Estimate'].apply(lambda x: x[1:4] + '-' + x[7:10] if len(x) == 28
                                                      else (x[1:3] + '-' + x[6:8] if len(x) == 26 
                                                            else (x[1:3] + '-' + x[6:9] if len(x) == 27 
                                                                  else ('35-50' if 'Hour' in x else 0))))

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df4.loc[df4['Salary_Estimate_No']==0].shape
# Out:
# (0, 16)

# %%
df4.Salary_Estimate[865][1:3] + '-' + df4.Salary_Estimate[865][6:9]
# Out:
# '59-101'

# %%
df4.loc[df4['type']=='Other']
# Out:
#                                              Job_Title  \
# 8                     Associate Director, Data Science
# 14                       Analytics Manager - Data Mart
# 38                     Head of Real-World Data Science
# 56                              Director, Data Science
# 61      Biotechnology SME with Data Science Experience
# 66                       Director of Data Architecture
# 69             Consultant - Data Science and Analytics
# 82                  Senior Data & Analytics Consultant
# 103                           Senior Analytics Manager
# 106                          Data Systems Specialist 2
# 109                                  Analytics Manager
# 121                 Associate Director of Data Science
# 126                                  Analytics Manager
# 132                                   VP, Data Science
# 139                        Senior Analytics Consultant
# 177                               Data Science Manager
# ...

# %% [markdown]
# # Others include modellers, researchers, advisors and interns

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df3 = df4.copy()

# %%
df3["Type"] = df3.pop('type')

# %%
df3
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df4 = df3.copy()

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df4.Type_of_ownership.unique()
# Out:
# array(['Company - Private', 'Company - Public', 'Government',
#        'Subsidiary or Business Segment', 'Non-profit Organisation',
#        'Private Practice / Firm', 'Hospital', 'Other Organisation', '-1',
#        'Unknown', 'College / University', 'Contract'], dtype=object)

# %%
year_group = df4.groupby(['Founded','Type'])

# %%
year_group.first()
# Out:
#                                                            Job_Title  \
# Founded Type
# -1      Analyst                                         Data Analyst
#         Engineer               Cyber Systems Engineer / Data Science
#         Other                                   Data Science Manager
#         Scientist                              Senior Data Scientist
#  1690   Scientist                                     Data Scientist
# ...                                                              ...
#  2017   Engineer                                Senior Data Engineer
#         Scientist  Principal Data Scientist with over 10 years ex...
#  2018   Engineer                           Machine Learning Engineer
#         Scientist                                     Data Scientist
#  2019   Scientist                                     Data Scientist
#
#                                       Salary_Estimate  \
# Founded Type
# ...

# %%
df4.corr()
# Out:
#           Rating  Founded
# Rating   1.00000  0.39046
# Founded  0.39046  1.00000

# %%
df4.isnull().values.any()
# Out:
# False

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df = df4.copy()

# %%
df['hourly'] = df['Salary_Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)

salary = df['Salary_Estimate'].apply(lambda x: x.split('(')[0])

minus_kd = salary.apply(lambda x: x.replace('K', '').replace('$',''))

min_hr = minus_kd.apply(lambda x: x.lower().replace('per hour', ''))

df['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df.min_salary + df.max_salary) / 2


# company name text only
df['company_name'] = df.apply(lambda x: x['Company_Name'] if x['Rating'] < 0 else x['Company_Name'][:-3], axis=1)

# state field
df['job_state'] = df['Location'].apply(lambda x: x.split(',')[-1] if len(x.split(',')) > 1 else -1)

df['job_in_HQ'] = df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis=1)

# age of company
df['age'] = df['Founded'].apply(lambda x: x if x < 1 else 2022 - x)

# parsing of job description (python, etc.)
# python
df['python_reqd'] = df['Job_Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

# r studio
df['r_reqd'] = df['Job_Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r.studio' in x.lower() else 0)

# SQL
df['sql_reqd'] = df['Job_Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0)

# Spark
df['spark_reqd'] = df['Job_Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)

# aws
df['aws_reqd'] = df['Job_Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)

# Excel 
df['excel_reqd'] = df['Job_Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)

# %%
df
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
del df['job_state']

# %%
df
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
pd.set_option('display.max_columns',35)

# %% [markdown]
# df.avg_salary[df.hourly == 1] = df.avg_salary * 2000

# %%
df
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job_Title           1000 non-null   object
#  1   Salary_Estimate     1000 non-null   object
#  2   Job_Description     1000 non-null   object
#  3   Rating              1000 non-null   float64
#  4   Company_Name        1000 non-null   object
#  5   Location            1000 non-null   object
#  6   Headquarters        1000 non-null   object
#  7   Size                1000 non-null   object
#  8   Founded             1000 non-null   int64
#  9   Type_of_ownership   1000 non-null   object
#  10  Industry            1000 non-null   object
#  11  Sector              1000 non-null   object
#  12  Revenue             1000 non-null   object
#  13  Competitors         1000 non-null   object
#  14  Salary_Estimate_No  1000 non-null   object
# ...

# %%
df5 = df.copy()

# %%
df5
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %% [markdown]
# # average salaries across domain

# %%
df5.avg_salary.mean()
# Out:
# 101.82

# %%
g1 = df5[df5['job_in_HQ']==1].groupby('Type')[['avg_salary']]

# %%
g1.mean()
# Out:
#            avg_salary
# Type
# Analyst     97.639535
# Engineer   108.580357
# Other       92.666667
# Scientist  101.176174

# %%
g2 = df5.groupby('Type')[['avg_salary']]

# %%
g2.mean()
# Out:
#            avg_salary
# Type
# Analyst     99.866667
# Engineer   101.328829
# Other      100.436364
# Scientist  102.185112

# %%
df = df5.copy()

# %% [markdown]
# # ratings and size effect?

# %%
df5.Rating.unique()
# Out:
# array([ 2.9,  4.1,  3.7,  3. ,  2.2,  3.6,  4. ,  3.5,  3.4,  4.9,  3.9,
#         3.3,  2. ,  3.8,  4.7,  5. ,  4.4,  2.8,  3.1,  2.3,  4.2, -1. ,
#         4.5,  4.3,  2.4,  4.6,  4.8,  2.7,  2.5,  2.6,  3.2,  1.5,  2.1,
#         1.9])

# %%
df4 = df5.copy()

# %%
pd.qcut(df4['Rating'], q=5)
# Out:
# 0      (-1.001, 3.3]
# 1         (4.0, 4.4]
# 2         (3.6, 4.0]
# 3      (-1.001, 3.3]
# 4         (3.6, 4.0]
#            ...
# 995       (4.4, 5.0]
# 996       (3.3, 3.6]
# 997       (3.3, 3.6]
# 998       (3.6, 4.0]
# 999       (3.6, 4.0]
# Name: Rating, Length: 1000, dtype: category
# Categories (5, interval[float64, right]): [(-1.001, 3.3] < (3.3, 3.6] < (3.6, 4.0] < (4.0, 4.4] < (4.4, 5.0]]

# %%
df4.Rating
# Out:
# 0      2.9
# 1      4.1
# 2      3.7
# 3      3.0
# 4      3.7
#       ...
# 995    5.0
# 996    3.6
# 997    3.6
# 998    3.9
# 999    3.8
# Name: Rating, Length: 1000, dtype: float64

# %%
df4['Rating_qcut'] = pd.qcut(df4['Rating'], q=4)

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df4['size'] = df4['Size'].apply(lambda x: x.split('e')[0])

# %%
df4['Size'] = df4['size'].apply(lambda x: x.replace('to', '-').replace('+',''))

# %%
g4 = df4.groupby('Size')[['avg_salary','min_salary','max_salary']]

# %%
g4.mean()
# Out:
#                avg_salary  min_salary  max_salary
# Size
# -1             106.907407   87.481481  126.333333
# 1 - 50         104.911538   85.630769  124.192308
# 10000          105.476821   86.973510  123.980132
# 1001 - 5000    102.280864   82.283951  122.277778
# 201 - 500       96.830645   79.612903  114.048387
# 5001 - 10000   102.590909   83.345455  121.836364
# 501 - 1000      98.293388   81.429752  115.157025
# 51 - 200        99.740000   80.185000  119.295000
# Unknown        110.250000   91.233333  129.266667

# %%
g3 = df4.groupby('Rating_qcut')[['avg_salary','min_salary','max_salary']]

# %%
g3.mean()
# Out:
#                avg_salary  min_salary  max_salary
# Rating_qcut
# (-1.001, 3.4]  102.991582   84.218855  121.764310
# (3.4, 3.8]     101.786344   83.484581  120.088106
# (3.8, 4.3]     101.497976   82.789474  120.206478
# (4.3, 5.0]     100.681223   81.340611  120.021834

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %% [markdown]
# # revenue

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %%
df4.Revenue.unique()
# Out:
# array(['Unknown / Non-Applicable', '₹100 to ₹500 billion (INR)',
#        '₹500+ billion (INR)', '₹100 to ₹500 million (INR)',
#        '₹10 to ₹50 billion (INR)', '₹10 to ₹50 million (INR)',
#        '₹50 to ₹100 billion (INR)', '₹5 to ₹10 billion (INR)',
#        '₹1 to ₹5 billion (INR)', '₹500 million to ₹1 billion (INR)', '-1',
#        '₹50 to ₹100 million (INR)', 'Less than ₹10 million (INR)'],
#       dtype=object)

# %%
g6 = df4.groupby('Revenue')[['avg_salary','min_salary','max_salary']]

# %%
g6.mean()
# Out:
#                                   avg_salary  min_salary  max_salary
# Revenue
# -1                                106.907407   87.481481  126.333333
# Less than ₹10 million (INR)        95.166667   74.000000  116.333333
# Unknown / Non-Applicable          103.616667   84.851515  122.381818
# ₹1 to ₹5 billion (INR)            100.881356   81.347458  120.415254
# ₹10 to ₹50 billion (INR)           98.793651   80.523810  117.063492
# ₹10 to ₹50 million (INR)          104.576923   86.615385  122.538462
# ₹100 to ₹500 billion (INR)        105.155000   85.590000  124.720000
# ₹100 to ₹500 million (INR)         91.975610   73.048780  110.902439
# ₹5 to ₹10 billion (INR)            91.587500   74.500000  108.675000
# ₹50 to ₹100 billion (INR)         102.000000   82.815789  121.184211
# ₹50 to ₹100 million (INR)          90.500000   73.250000  107.750000
# ₹500 million to ₹1 billion (INR)  100.045455   80.227273  119.863636
# ...

# %%
g7 = df4.groupby('job_in_HQ')[['avg_salary','min_salary','max_salary']]

# %%
g7.mean()
# Out:
#            avg_salary  min_salary  max_salary
# job_in_HQ
# 0          102.236979   83.534722  120.939236
# 1          101.253538   82.367925  120.139151

# %%
g8 = df4.groupby('python_reqd')[['avg_salary','min_salary','max_salary']]

# %%
g8.mean()
# Out:
#              avg_salary  min_salary  max_salary
# python_reqd
# 0             99.676036   81.420118  117.931953
# 1            102.914653   83.867069  121.962236

# %% [markdown]
# # age

# %%
df4['age_qcut'] = pd.qcut(df4['age'], q=5)

# %%
df4.age_qcut.unique()
# Out:
# [(14.0, 24.0], (49.0, 332.0], (-1.001, 6.0], (6.0, 14.0], (24.0, 49.0]]
# Categories (5, interval[float64, right]): [(-1.001, 6.0] < (6.0, 14.0] < (14.0, 24.0] < (24.0, 49.0] < (49.0, 332.0]]

# %%
g10 = df4.groupby('age_qcut')[['avg_salary','min_salary','max_salary']]

# %%
g10.mean()
# Out:
#                avg_salary  min_salary  max_salary
# age_qcut
# (-1.001, 6.0]  104.983173   85.817308  124.149038
# (6.0, 14.0]     99.300459   81.197248  117.403670
# (14.0, 24.0]   100.888298   81.888298  119.888298
# (24.0, 49.0]    99.313830   80.861702  117.765957
# (49.0, 332.0]  104.535354   85.313131  123.757576

# %%
sns.stripplot(x="sql_reqd", y="avg_salary", data=df4);

# %%
sns.barplot(x='Type', y='avg_salary', hue='python_reqd', data=df4);

# %%
sns.barplot(x='Type', y='avg_salary', hue='aws_reqd', data=df4);

# %%
sns.barplot(x='Type', y='avg_salary', hue='sql_reqd', data=df4);

# %%
sns.barplot(x='Type', y='avg_salary', hue='excel_reqd', data=df4);

# %%
df4
# Out:
#                                              Job_Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary_Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# ...

# %% [markdown]
# <b> gg
#
# **gg**
#
# __gg__
#
#
# *Italic*
#
# _Italic_
#
#
# - Bullet
#
#
#     - Subbullet
#
#
# [test](https://www.youtube.com/watch?v=Upcs6OCgnow)

# %%
len(df4.Competitors.unique())
# Out:
# 201
